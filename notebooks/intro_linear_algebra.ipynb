# %%
import os
import pyreadr as pyr
import pandas as pd
import numpy as np
import plotly.express as px
from pathlib import Path

# %% [markdown]
# #### Álgebra lineal con Numpy

# %%
b = np.array([1, 2, 3])
b
# Out:
# array([1, 2, 3])

# %%
### Se puede usar la función np.arange
c = np.arange(1, 8)
c
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
### Un vector con todos los elemento iguales a 1
d = np.ones(3)
d
# Out:
# array([1., 1., 1.])

# %%
### Transponiendo el vector
np.transpose(b)
# Out:
# array([1, 2, 3])

# %% [markdown]
# ### Suma y resta de vectores

# %%
x = np.array([1, 5])
y = np.array([2, 4])

x + y
# Out:
# array([3, 9])

# %%
### La resta es similar
x - y
# Out:
# array([-1,  1])

# %% [markdown]
# ### Multiplicación por un escalar

# %%
x * 4
# Out:
# array([ 4, 20])

# %%
y * 6
# Out:
# array([12, 24])

# %% [markdown]
# ### Producto escalar

# %%
np.dot(x, y)
# Out:
# np.int64(22)

# %% [markdown]
# ### Norma de un vector

# %%
np.linalg.norm(x)
# Out:
# np.float64(5.0990195135927845)
